# %% [markdown]
# Evaluación Final — FASE 1
# BLOQUE A — Python + lógica
# 1.
#
# Tenés esta lista:
#
# nums = [3, 7, 2, 9, 4]
#
# Generá una nueva lista con los cuadrados de los números mayores a 4 usando list comprehension.
#
# 2.
#
# Explicá brevemente diferencia entre:
#
# lista = []
# array = np.array([])
# BLOQUE B — NumPy
# 3.
#
# Dado:
#
# a = np.array([2,4,6])
# b = np.array([1,3,5])
#
# ¿Qué devuelve?
#
# a + b
# a * b
# np.dot(a,b)
# 4.
#
# ¿Para qué sirve np.linspace(0,10,6) y qué devuelve aproximadamente?
#
# BLOQUE C — Pandas
# 5.
#
# Tenés DataFrame df.
#
# ¿Cómo hacés para mostrar solo filas donde ventas > 100?
#
# 6.
#
# ¿Cómo crearías columna nueva llamada iva igual al 21% de ventas?
#
# BLOQUE D — Estadística
# 7.
#
# Diferencia práctica entre:
#
# media
# mediana
#
# ¿Cuándo preferís mediana?
#
# 8.
#
# Si un dataset tiene:
#
# media = 100
# std = 2
#
# ¿Qué interpretás?
#
# Y si tiene:
#
# media = 100
# std = 80
# 9.
#
# ¿Qué indica una correlación de:
#
# 0.92
# 0.03
# -0.88
# BLOQUE E — Machine Learning
# 10.
#
# Explicá con tus palabras qué hacen:
#
# modelo.fit(X,y)
# modelo.predict([[75]])
# 11.
#
# Si cambia fuerte el dataset, ¿qué suele haber que hacer y por qué?
#
# BLOQUE F — Pensamiento analítico
# 12.
#
# Tenés datos de precios de casas:
#
# 80k, 82k, 79k, 81k, 900k
#
# ¿Qué sospechás?
# ¿Qué métricas mirarías?
# ¿Qué harías antes de entrenar modelo?
#
# Cómo responder
#
# Podés responder resumido:
#
# 1.
# 2.
# 3.
# ...
#
# Cuando me lo mandes, te doy:
#
# Resultado final
# Nivel alcanzado
# Si aprobaste FASE 1
# Qué te conviene estudiar en FASE 2

# %% [markdown]
# cuadrados = [x ** 2 for x in nums if x > 4] print(cuadrados)
#
# Una lista es una estructura de datos de base de python, un np array es una estructura de datos de NumbPy libreria que esta preparada para realizar operaciones de manera mucho mas eficiente
#
# a + b = [3,7,11] a * b = [2, 12, 30] np.dot(a,b) = 44
#
# Va a devolver 6 datos con numeros entre 0 y 10 incluyendo 0 y 10
#
# df[df["ventas"] > 100]
#
# df["iva"] = df["ventas"] * .21
#
# La media es el resultado de la suma de todos los elementos dividido por la cantidad de elementos La mediana es el elemento con mas apariciones
#
# Para una media de 100 la desvicaicon estandar es 2, por lo cual la media por si sola es fiable en el caso dos, con una desviacion estandar de 80, habria que revisar percentiles, ya que pareciera que dentro de la distribucion de datos hay mucha diferencia u anomalias en el espacio muestral
#
# .92 es muy cerca a un crecimiento proporcional entre dos variables .03 es muy cerca a que no exista relacion entre dos variables -0.88 es muy cerca a una relacion inversa entre dos variables
#
# Carga dentro del modelo los valores de los datos almacenados en x e y y predice para el resultado probable segun los datos cargados para un input de 75
#
# Re entrenar el modelo
#
# Sospecho que el valor de 900k tendria que tomarse con cuidado, por que esta muy lejos del resto Probablemente la media no me sirva, ni la mediana tampoco, tomaria mas peso de los percentiles Lo excluiria del entrenamiento para realizar predicciones
