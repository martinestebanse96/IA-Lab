# %%
import pandas as pd

datos = {
    "nombre": ["Ana", "Luis", "Martin", "Julia"],
    "edad": [22, 35, 30, 28],
    "ventas": [100, 150, 130, 170]
}

df = pd.DataFrame(datos)

#print(df)

#df.head()
#df.info()
#df.describe()

#df["nombre"]
#df["ventas"]

#df[["nombre", "ventas"]]

#df[df["edad"] > 28]

#df["bonus"] = df["ventas"] * 0.10

#df.sort_values("ventas", ascending=False)

df["ventas"].mean()
df["edad"].mean()
# Out:
# np.float64(28.75)

# %%
df_csv = pd.read_csv("ventas.csv")

#mostrar solo mayores de 30 años
df_csv[df_csv["edad"] > 30]

#promedio de ventas
df_csv["ventas"].mean()
#persona con mayor venta
df_csv[df_csv["ventas"] == df_csv["ventas"].max()]
#nueva columna ventas_anual = ventas * 12
df_csv["ventas_annual"] = df_csv["ventas"] * 12
