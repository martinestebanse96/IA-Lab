# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from sklearn.tree import export_text

# %%
df = pd.DataFrame({
    "cpu": [20,30,40,85,90,95,35,50,88,92],
    "ram": [30,35,40,80,85,90,45,50,82,91],
    "caida": [0,0,0,1,1,1,0,0,1,1]
})

# %%
X = df[["cpu","ram"]]
y = df["caida"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
modelo = DecisionTreeClassifier(
    max_depth=3,
    min_samples_split=4,
    min_samples_leaf=2,
    random_state=42
)

modelo.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=2, min_samples_split=4,
#                        random_state=42)

# %%
pred = modelo.predict(X_test)
print(pred)
# Out:
# [1 0 1]

# %%
print(accuracy_score(y_test, pred))
# Out:
# 1.0

# %%
print(modelo.feature_importances_)
# Out:
# [1. 0.]

# %%
plt.figure(figsize=(12,8))
plot_tree(modelo, feature_names=X.columns, filled=True)
plt.show()

# %%
export_text(modelo)
# Out:
# '|--- feature_0 <= 67.50\n|   |--- class: 0\n|--- feature_0 >  67.50\n|   |--- class: 1\n'
