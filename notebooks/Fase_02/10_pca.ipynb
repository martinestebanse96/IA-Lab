# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.DataFrame({
    "cpu": [20,30,80,90,50],
    "ram": [25,35,78,88,52],
    "disk": [40,42,70,72,50]
})

# %%
X = StandardScaler().fit_transform(df)

# %%
modelo = PCA(n_components=2)
X_pca = modelo.fit_transform(X)
print(X_pca)
# Out:
# [[-2.07590978  0.13770696]
#  [-1.54067152 -0.06237354]
#  [ 1.7272728   0.14547781]
#  [ 2.26251105 -0.0546027 ]
#  [-0.37320256 -0.16620852]]

# %%
print(modelo.explained_variance_ratio_)
# Out:
# [0.99498519 0.00497495]
