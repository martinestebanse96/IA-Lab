# %%
import numpy as np

# %%
x = np.array([2, 5, 1])

# %%
X = np.array([
    [2,5,1],
    [1,3,0],
    [4,2,7]
])

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# %%
#Producto de punto
#a⋅b=1⋅4+2⋅5+3⋅6=32
np.dot(a,b)
# Out:
# np.int64(32)

# %%
y = 2*x + 1

# %%
y = [2, 3]
z = [4, 5]

np.dot(y,z)
# Out:
# np.int64(23)
