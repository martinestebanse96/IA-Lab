# %%
import pandas as pd

df = pd.read_csv("ventas.csv")

# %%
#df["ventas"].mean()
#df["ventas"].median()
df["ventas"].mode()
# Out:
# 0    100
# 1    130
# 2    150
# 3    170
# 4    190
# Name: ventas, dtype: int64

# %%
#df["ventas"].std()
df["ventas"].var()
# Out:
# np.float64(1220.0)

# %%
#df["ventas"].min()
df["ventas"].max()
# Out:
# np.int64(190)

# %%
#df["ventas"].quantile(0.25)
#df["ventas"].quantile(0.50)
df["ventas"].quantile(0.75)
# Out:
# np.float64(170.0)

# %%
df["clientes"] = [10, 15, 13, 18, 20]
df[["ventas", "clientes"]].corr()
# Out:
#             ventas  clientes
# ventas    1.000000  0.997124
# clientes  0.997124  1.000000

# %%
import matplotlib.pyplot as plt

df["ventas"].hist()
plt.show()

# %%
#media de edad
df["edad"].mean()
# Out:
# np.float64(31.2)

# %%
#correlación edad vs ventas
df[["edad", "ventas"]].corr()
# Out:
#             edad    ventas
# edad    1.000000  0.529209
# ventas  0.529209  1.000000

# %%
#mediana ventas
df["ventas"].mean()
# Out:
# np.float64(138.0)

# %%
#desviación estándar ventas
df["ventas"].std()
# Out:
# np.float64(40.8656334834051)
